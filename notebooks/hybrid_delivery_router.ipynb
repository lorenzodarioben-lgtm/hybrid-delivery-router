# %% [markdown]
# # Hybrid Delivery Router
#
# This notebook is a lightweight demo of the package in `src/`. The main implementation is regular Python code with tests; this notebook is for exploration and presentation.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "src").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT / "src"))

from hybrid_delivery_router import BoxHillDeliveryMap, FuzzySpeedController
from hybrid_delivery_router.evaluation import master_comparison, sensitivity_analysis

# %% [markdown]
# ## Map and Controller

# %%
env = BoxHillDeliveryMap()
controller = FuzzySpeedController()
env.summary(), {k: round(v, 1) for k, v in controller.cons_centroid.items()}

# %% [markdown]
# ## Master Comparison

# %%
import pandas as pd

pd.DataFrame(master_comparison())

# %% [markdown]
# ## Sensitivity Analysis

# %%
pd.DataFrame(sensitivity_analysis())
